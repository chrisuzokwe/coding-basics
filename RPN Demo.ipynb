# %% [markdown]
# ##### connect to drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
cd "/content/gdrive/MyDrive/Master's Thesis 2020-2021/Detectron2 Model/data"

# %% [markdown]
# ##### load modules + data

# %%
# load song
# load rpn
# predict on song
# vizualise
